# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#Plotting a house using Matplotlib

#First,I made a sketch on a paper to get the (x,y)points of the structure and modified while
#plotting using matplotlib

fig, ax=plt.subplots(figsize=(25,25))
ax.axis([1,20,1,20])

#Plotting the structure of the house. 
plt.plot(4,4,'g*')
plt.plot(16,4,'g*')
plt.plot(4,12,'g*')
plt.plot(16,12,'g*')
plt.plot([4,16,16,4,4],[4,4,12,12,4],'r',linewidth=5)
plt.plot(10,17,'*')

#Plotting the door
door_a=np.array([12,12,15,15])
door_b=np.array([4,9,9,4])
plt.plot(door_a,door_b,'r')
door_c=np.array([11.9,11.9,15.1,15.1])
door_d=np.array([3.9,9.1,9.1,3.9])
plt.plot(door_c,door_d,'cyan')

#Plotting the roof of the house
roof_a=np.array([4,10,16])
roof_b=np.array([12,17,12])
roof=plt.plot(roof_a,roof_b,linewidth=4)

plt.plot(4.6,12.5,'*')
plt.plot(15.4,12.5,'*')
roof_design=plt.plot([4.6,15.5],[12.5,12.5])
roof_design=plt.plot([5.8,14.2],[13.5,13.5])
roof_design=plt.plot([6.4,13.6],[14,14])
roof_design=plt.plot([7.6,12.4],[15,15])
roof_design=plt.plot([8.2,11.8],[15.5,15.5])

#Plotting the door
door_knob=plt.plot(12.4,6,'go',markersize=25)
door_knob=plt.plot(12.4,6,'ro',markersize=10)

#Plotting the chimney
chimney=plt.plot([6,6],[13.7,16],'b')
chimney=plt.plot([7,7],[14.5,16],'b')
chimney=plt.plot([5.5,7.5],[16,16],'b', linestyle='--')
chimney=plt.plot([5.5,7.5],[16.2,16.2],'b', linestyle='--')

#Plotting the windows

window1=plt.plot([4.5,7,7,4.5,4.5],[7.5,7.5,9.5,9.5,7.5])
window1_design=plt.plot([5.7,5.7],[8,9.4],'c')
window1_design=plt.plot([4.5,7.0],[7.9,7.9],'r')
window1_design=plt.plot([4.6,6.9,6.9,4.6,4.6],[8,8,9.4,9.4,8],'r')
window1_design=plt.plot([4.5,7.0],[7.9,7.9],'r')
window1_design=plt.plot([4.6,6.9],[8.7,8.7],'r')

window2=plt.plot([7.5,10,10,7.5,7.5],[7.5,7.5,9.5,9.5,7.5],'c')
window2_design=plt.plot([8.7,8.7],[8,9.4],'c')
window2_design=plt.plot([7.5,10.0],[7.9,7.9],'r')
window2_design=plt.plot([7.6,9.9,9.9,7.6,7.6],[8,8,9.4,9.4,8],'r')
window2_design=plt.plot([7.5,10.0],[7.9,7.9],'r')
window2_design=plt.plot([7.6,9.9],[8.7,8.7],'r')

#Sun
sun=plt.plot(18,18,'o',color='yellow',markersize=100)
stars=plt.plot(4,18,'*',markersize=10,color='black')
stars=plt.plot(5,18.5,'*',markersize=20,color='black')
stars=plt.plot(6,19,'*',markersize=10,color='black')
stars=plt.plot(10,18.5,'*',markersize=20,color='black')
stars=plt.plot(7,18,'*',markersize=10,color='black')
stars=plt.plot(8,18.5,'*',markersize=20,color='black')
stars=plt.plot(11,19,'*',markersize=10,color='black')
stars=plt.plot(10,18.5,'*',markersize=20,color='black')
stars=plt.plot(4,17,'*',markersize=10,color='black')

#Trees
Tree=plt.plot([18,18],[4.5,1],'g')
Tree=plt.plot([18.5,18.5],[4.5,1],'g')
tree_top=plt.plot(17.3,5,'o',color='green',markersize=130)
tree_top=plt.plot(19,5,'o',color='green',markersize=130)
tree_top=plt.plot(18.2,6.3,'o',color='green',markersize=130)

Tree=plt.plot([2.2,2.2],[4.5,1],'g')
Tree=plt.plot([2.7,2.7],[4.5,1],'g')
tree_top=plt.plot(1.8,5,'o',color='green',markersize=105)
tree_top=plt.plot(3.2,5,'o',color='green',markersize=105)
tree_top=plt.plot(2.5,5.8,'o',color='green',markersize=105)

#Painting the sky blue
x1=np.array([0,0,20,20,0])
y1=np.array([20,7.5,7.5,20,20])
ax.fill_between(x1,y1,color='skyblue')

#Text for my door
plt.text(12,7,'WELCOME HOME')
roof_a=np.array([4,10,16])
roof_b=np.array([12,17,12])
ax.fill_between(roof_a,roof_b,color='white')

#Modifying text size
plt.rcParams.update({'font.size':20})

# %% [markdown]
# #### I made a house with a blue sky showing sun and stars. Also, There are two trees by the side of the house. The house has two windows.The door has a door knob. Also, there is a chimney on the roof of the house.
